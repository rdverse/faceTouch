# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import preprocessing

df_stand = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\standing.csv')
df_sit = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\sitting_chair.csv')
df_upstair = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\walk_upstairs.csv')
df_walk = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\walking.csv')
df_facet = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\touching_face.csv')
df_schead = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\scratching_head.csv')
df_rubface = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\rub_face.csv')
df_scface = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\scratching_face.csv')


df_check_phone = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\check_phone.csv')
df_clean_window = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\clean_window.csv')
df_cooking = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\cooking.csv')
df_only_close_door = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\only_close_door.csv')
df_only_open_door = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\only_open_door.csv')


df_pick_chocolate = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\pick_chocolate.csv')
df_place_item = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\place_item.csv')
df_typing = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\typing.csv')
df_walk_downstairs = pd.read_csv (r'C:\Users\SDG\Desktop\Data\Working_data\walk_downstairs.csv')

names = df_stand.columns
df_list=['df_stand', 'df_sit', 'df_upstair', 'df_walk', 'df_facet', 'df_schead', 'df_rubface', 'df_scface']

# %%
# scaler = preprocessing.StandardScaler()
# for name in df_list:
#     name = pd.DataFrame(scaler.fit_transform(name.values), columns=name.columns, index=name.index)
# df_stand

# %%
scaler = preprocessing.StandardScaler()
d_stand = scaler.fit_transform(df_stand)
d_sit = scaler.fit_transform(df_sit)
d_upstair = scaler.fit_transform(df_upstair)
d_walk = scaler.fit_transform(df_walk)
d_facet = scaler.fit_transform(df_facet)
d_schead = scaler.fit_transform(df_schead)
d_rubface = scaler.fit_transform(df_rubface)
d_scface = scaler.fit_transform(df_scface)
d_check_phone = scaler.fit_transform(df_check_phone)
d_clean_window = scaler.fit_transform(df_clean_window)
d_cooking = scaler.fit_transform(df_cooking)
d_only_close_door = scaler.fit_transform(df_only_close_door)
d_only_open_door = scaler.fit_transform(df_only_open_door)
d_pick_chocolate = scaler.fit_transform(df_pick_chocolate)
d_place_item = scaler.fit_transform(df_place_item)
d_typing = scaler.fit_transform(df_typing)
d_walk_downstairs = scaler.fit_transform(df_walk_downstairs)

scaled_df_stand = pd.DataFrame(d_stand, columns=names)
scaled_df_sit = pd.DataFrame(d_sit, columns=names)
scaled_df_upstair = pd.DataFrame(d_upstair, columns=names)
scaled_df_walk = pd.DataFrame(d_walk, columns=names)
scaled_df_facet = pd.DataFrame(d_facet, columns=names)
scaled_df_schead = pd.DataFrame(d_schead, columns=names)
scaled_df_rubface = pd.DataFrame(d_rubface, columns=names)
scaled_df_scface = pd.DataFrame(d_scface, columns=names)
scaled_df_check_phone = pd.DataFrame(d_check_phone, columns=names)
scaled_df_clean_window = pd.DataFrame(d_clean_window, columns=names)
scaled_df_cooking = pd.DataFrame(d_cooking, columns=names)
scaled_df_only_close_door = pd.DataFrame(d_only_close_door, columns=names)
scaled_df_only_open_door = pd.DataFrame(d_only_open_door, columns=names)
scaled_df_pick_chocolate = pd.DataFrame(d_pick_chocolate, columns=names)
scaled_df_place_item = pd.DataFrame(d_place_item, columns=names)
scaled_df_typing = pd.DataFrame(d_typing, columns=names)
scaled_df_walk_downstairs = pd.DataFrame(d_walk_downstairs, columns=names)


scaled_df_stand = scaled_df_stand.sample(n=300,replace=True)
scaled_df_sit = scaled_df_sit.sample(n=300,replace=True)
scaled_df_upstair = scaled_df_upstair.sample(n=300,replace=True)
scaled_df_walk = scaled_df_walk.sample(n=300,replace=True)
scaled_df_facet = scaled_df_facet.sample(n=300,replace=True)
scaled_df_schead = scaled_df_schead.sample(n=300,replace=True)
scaled_df_rubface = scaled_df_rubface.sample(n=300,replace=True)
scaled_df_scface = scaled_df_scface.sample(n=300,replace=True)
scaled_df_check_phone = scaled_df_check_phone.sample(n=300,replace=True)
scaled_df_clean_window = scaled_df_clean_window.sample(n=300,replace=True)
scaled_df_cooking = scaled_df_cooking.sample(n=300,replace=True)
scaled_df_only_close_door = scaled_df_only_close_door.sample(n=300,replace=True)
scaled_df_only_open_door = scaled_df_only_open_door.sample(n=300,replace=True)
scaled_df_pick_chocolate = scaled_df_pick_chocolate.sample(n=300,replace=True)
scaled_df_place_item = scaled_df_place_item.sample(n=300,replace=True)
scaled_df_typing = scaled_df_typing.sample(n=300,replace=True)
scaled_df_walk_downstairs = scaled_df_walk_downstairs.sample(n=300,replace=True)

# %%
#standing
col_x1=scaled_df_stand['Accel_WR_X_CAL']
col_y1=scaled_df_stand['Accel_WR_Y_CAL']
col_z1=scaled_df_stand['Accel_WR_Z_CAL']

#sitting
col_x2=scaled_df_sit['Accel_WR_X_CAL']
col_y2=scaled_df_sit['Accel_WR_Y_CAL']
col_z2=scaled_df_sit['Accel_WR_Z_CAL']

#walking_upstairs
col_x3=scaled_df_upstair['Accel_WR_X_CAL']
col_y3=scaled_df_upstair['Accel_WR_Y_CAL']
col_z3=scaled_df_upstair['Accel_WR_Z_CAL']

#walking
col_x4=scaled_df_walk['Accel_WR_X_CAL']
col_y4=scaled_df_walk['Accel_WR_Y_CAL']
col_z4=scaled_df_walk['Accel_WR_Z_CAL']

#touching_face
col_x5=scaled_df_facet['Accel_WR_X_CAL']
col_y5=scaled_df_facet['Accel_WR_Y_CAL']
col_z5=scaled_df_facet['Accel_WR_Z_CAL']

#scratching head
col_x6=scaled_df_schead['Accel_WR_X_CAL']
col_y6=scaled_df_schead['Accel_WR_Y_CAL']
col_z6=scaled_df_schead['Accel_WR_Z_CAL']

#rubbing face
col_x7=scaled_df_rubface['Accel_WR_X_CAL']
col_y7=scaled_df_rubface['Accel_WR_Y_CAL']
col_z7=scaled_df_rubface['Accel_WR_Z_CAL']

#scratching face
col_x8=scaled_df_scface['Accel_WR_X_CAL']
col_y8=scaled_df_scface['Accel_WR_Y_CAL']
col_z8=scaled_df_scface['Accel_WR_Z_CAL']

# %%
# Create the figure
fig = plt.figure()
fig.set_size_inches(18.5, 10.5)
ax = fig.add_subplot(1, 2, 1, projection='3d')


# Plot the values 1st axis(similar acts)
l1=ax.scatter(col_x1, col_y1, col_z1, c = 'b', marker='o', s=100)
l2=ax.scatter(col_x2, col_y2, col_z2, c = 'r', marker='^', s=100)
l3=ax.scatter(col_x3, col_y3, col_z3, c = 'g', marker='*', s=100)

ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')

# Plot the values 2nd axis(dissimilar acts)
ax1 = fig.add_subplot(1, 2, 2, projection='3d')
l1=ax1.scatter(col_x1, col_y1, col_z1, c = 'b', marker='o', s=100)
l4=ax1.scatter(col_x4, col_y4, col_z4, c = 'y', marker='^', s=100)
l5=ax1.scatter(col_x5, col_y5, col_z5, c = 'grey', marker='*', s=100)

plt.legend((l1, l2, l3, l4, l5), ('standing', 'stitting_chair', 'upstairs', 'walking', 'touching_face'))

ax1.set_xlabel('X-axis')
ax1.set_ylabel('Y-axis')
ax1.set_zlabel('Z-axis')

plt.show()

# %%
uni_features=['Accel_LN_X_CAL', 'Accel_LN_Y_CAL', 'Accel_LN_Z_CAL', 'Accel_WR_X_CAL', 'Accel_WR_Y_CAL', 'Accel_WR_Z_CAL', 
             'Gyro_X_CAL', 'Gyro_Y_CAL', 'Gyro_Z_CAL', 'Resultant_Accel']

# %% [markdown]
# Univariant distribution of features for one person

# %%
plt.subplots(figsize=(30, 30)) 
for i, name in enumerate(uni_features):
    plt.subplot(3, 4, i+1)
    plt.scatter(scaled_df_stand.index, scaled_df_stand[name])
    plt.xlabel(name)
    plt.ylabel('index')

# %% [markdown]
# Comparision of every feature for two different activity

# %%
plt.subplots(figsize=(30, 30)) 
for i, name in enumerate(uni_features):
    plt.subplot(3, 4, i+1)
    l1=plt.scatter(scaled_df_stand[name], scaled_df_stand.index, c='red')
    l2=plt.scatter(scaled_df_sit[name], scaled_df_sit.index, c='green')
    plt.xlabel(name)
    plt.ylabel('index')
    plt.legend((l1, l2), ('standing', 'stitting_chair'))
#Note: GSR skin conductance showed difference for standing and sitting activity

# %% [markdown]
# Analyzing scratching head and scratching face

# %%
#plotting feature wise
plt.subplots(figsize=(30, 30)) 
for i, name in enumerate(uni_features):
    plt.subplot(3, 4, i+1)
    l1=plt.scatter(scaled_df_schead[name], scaled_df_schead.index, c='red')
    l2=plt.scatter(scaled_df_scface[name], scaled_df_scface.index, c='green')
    plt.xlabel(name)
    plt.ylabel('index')
    plt.legend((l1, l2), ('scratching head', 'scratching face'))

# %%
# plotting Accelerometer Wide range
# %matplotlib qt
fig = plt.figure()
fig.set_size_inches(18.5, 10.5)
ax1 = fig.add_subplot(1, 2, 1, projection='3d')

l4=ax1.scatter(scaled_df_schead['Accel_WR_X_CAL'], scaled_df_schead['Accel_WR_Y_CAL'], scaled_df_schead['Accel_WR_Z_CAL'], c = 'red', marker='*', s=100)
l6=ax1.scatter(scaled_df_scface['Accel_WR_X_CAL'], scaled_df_scface['Accel_WR_Y_CAL'], scaled_df_scface['Accel_WR_Z_CAL'], c = 'green', marker='^', s=100)

plt.legend((l4, l6), ('scratching head', 'scratching face'))

ax1.set_xlabel('X-axis')
ax1.set_ylabel('Y-axis')
ax1.set_zlabel('Z-axis')

plt.show()

# %%
# plotting Gyroscope data
# %matplotlib qt
fig = plt.figure()
fig.set_size_inches(18.5, 10.5)
ax1 = fig.add_subplot(1, 2, 1, projection='3d')

l4=ax1.scatter(scaled_df_schead['Gyro_X_CAL'], scaled_df_schead['Gyro_Y_CAL'], scaled_df_schead['Gyro_Z_CAL'], c = 'red', marker='*', s=100)
l6=ax1.scatter(scaled_df_scface['Gyro_X_CAL'], scaled_df_scface['Gyro_Y_CAL'], scaled_df_scface['Gyro_Z_CAL'], c = 'green', marker='^', s=100)

plt.legend((l4, l6), ('scratching head', 'scratching face'))

ax1.set_xlabel('X-axis')
ax1.set_ylabel('Y-axis')
ax1.set_zlabel('Z-axis')

plt.show()

# %%
# plotting GSR data
# %matplotlib inline
fig = plt.figure()

l1=plt.scatter(scaled_df_schead['GSR_Skin_Resistance_CAL'], scaled_df_schead['GSR_Skin_Conductance_CAL'], c='red')
l2=plt.scatter(scaled_df_scface['GSR_Skin_Resistance_CAL'], scaled_df_scface['GSR_Skin_Conductance_CAL'], c='green')
plt.xlabel('GSR_Skin_Resistance_CAL')
plt.ylabel('GSR_Skin_Conductance_CAL')
plt.legend((l1, l2), ('scratching head', 'scratching face'))

plt.show()

# %%
new1 = scaled_df_stand.filter(uni_features)
new1['result']='non face'
new2 = scaled_df_sit.filter(uni_features)
new2['result']='non face'
new3 = scaled_df_upstair.filter(uni_features)
new3['result']='non face'
new4 = scaled_df_walk.filter(uni_features)
new4['result']='non face'
new5 = scaled_df_check_phone.filter(uni_features)
new5['result']='non face'
new6 = scaled_df_clean_window.filter(uni_features)
new6['result']='non face'
new7 = scaled_df_cooking.filter(uni_features)
new7['result']='non face'
new8 = scaled_df_only_close_door.filter(uni_features)
new8['result']='non face'
new9 = scaled_df_only_open_door.filter(uni_features)
new9['result']='non face'
new10 = scaled_df_pick_chocolate.filter(uni_features)
new10['result']='non face'
new11 = scaled_df_place_item.filter(uni_features)
new11['result']='non face'
new12 = scaled_df_typing.filter(uni_features)
new12['result']='non face'
new13 = scaled_df_walk_downstairs.filter(uni_features)
new13['result']='non face'
new14 = scaled_df_facet.filter(uni_features)
new14['result']='face'
new15 = scaled_df_schead.filter(uni_features)
new15['result']='face'
new16 = scaled_df_rubface.filter(uni_features)
new16['result']='face'
new17 = scaled_df_scface.filter(uni_features)
new17['result']='face'

frames= [new1, new2, new3, new4, new5, new6, new7, new8, new9, new10, new11, new12, new13, new14, new15, new16, new17]
merged_df= pd.concat(frames)
merged_df

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# generate dataset
X, y = merged_df.iloc[:, :-1], merged_df.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)
#X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.33, random_state=0)

# l1 lasso l2 ridge
grid={"C":np.logspace(-3,3,7), "penalty":["l1","l2"]}
logisticRegr = LogisticRegression()
logreg_cv=GridSearchCV(logisticRegr,grid,cv=10)

logreg_cv.fit(X_train, y_train)
print("tuned hpyerparameters :(best parameters) ",logreg_cv.best_params_)
print("Training accuracy :",logreg_cv.best_score_)


logreg2=LogisticRegression(C=0.001,penalty="l2")
logreg2.fit(X_train,y_train)
print("Testing accuracy",logreg2.score(X_test,y_test))
# Out:
# tuned hpyerparameters :(best parameters)  {'C': 0.001, 'penalty': 'l2'}
# Training accuracy : 0.7679254343091355
# Testing accuracy 0.7581699346405228

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.preprocessing import PolynomialFeatures
from pandas import DataFrame
from sklearn.pipeline import Pipeline

# generate dataset
X, y = merged_df.iloc[:, :-1], merged_df.iloc[:, -1]
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.33, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.33, random_state=0)

poly = PolynomialFeatures(degree = 2, interaction_only=False, include_bias=False)
X_poly = poly.fit_transform(X_train)
print(X_poly.shape)

lr = LogisticRegression(max_iter=1000)

pipe = Pipeline([('polynomial_features',poly), ('logistic_regression',lr)])
pipe.fit(X_train, y_train)

print("Training Score:{:.3f}".format(pipe.score(X_train, y_train)))
print("Validation Score:{:.3f}".format(pipe.score(X_val, y_val)))
print("Testing Score:{:.3f}".format(pipe.score(X_test, y_test)))
# Out:
# (2289, 65)
# Training Score:0.857
# Validation Score:0.853
# Testing Score:0.842

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.preprocessing import PolynomialFeatures
from pandas import DataFrame
from sklearn.pipeline import Pipeline

# generate dataset
X, y = merged_df.iloc[:, :-1], merged_df.iloc[:, -1]
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.33, random_state=0)
#X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.33, random_state=0)

poly = PolynomialFeatures(degree = 2, interaction_only=False, include_bias=False)
X_poly = poly.fit_transform(X_train)
print(X_poly.shape)

# l1 lasso l2 ridge
grid={"C":np.logspace(-3,3,7), "penalty":["l1","l2"]}
lr = LogisticRegression(max_iter=1000)
logreg_cv=GridSearchCV(lr,grid,cv=10)


pipe = Pipeline([('polynomial_features',poly), ('logistic_regression',logreg_cv)])
pipe.fit(X_train, y_train)

print("tuned hpyerparameters :(best parameters) ",logreg_cv.best_params_)

print("Training Score:{:.3f}".format(pipe.score(X_train, y_train)))
#print("Validation Score:{:.3f}".format(pipe.score(X_val, y_val)))
print("Testing Score:{:.3f}".format(pipe.score(X_test, y_test)))
# Out:
# (2289, 65)
# tuned hpyerparameters :(best parameters)  {'C': 1000.0, 'penalty': 'l2'}
# Training Score:0.878
# Testing Score:0.860

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.preprocessing import PolynomialFeatures
from pandas import DataFrame
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder

# generate dataset
ord_enc = OrdinalEncoder()
merged_df["result"] = ord_enc.fit_transform(merged_df[["result"]])
X, y = merged_df.iloc[:, :-1], merged_df.iloc[:, -1]
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, random_state=0)

rf = RandomForestRegressor(n_estimators = 1000)

rf.fit(X_train, y_train)


print("Training Score:{:.3f}".format(rf.score(X_train, y_train)))
print("Validation Score:{:.3f}".format(rf.score(X_val, y_val)))
print("Testing Score:{:.3f}".format(rf.score(X_test, y_test)))
# Out:
# Training Score:0.945
# Validation Score:0.604
# Testing Score:0.554

# %%
feature_imp = pd.Series(rf.feature_importances_,index=X_train.columns).sort_values(ascending=False)
feature_imp
# Out:
# Accel_WR_Y_CAL     0.136948
# Resultant_Accel    0.120756
# Accel_LN_X_CAL     0.105530
# Gyro_Z_CAL         0.105057
# Accel_WR_Z_CAL     0.102814
# Accel_LN_Y_CAL     0.102809
# Accel_WR_X_CAL     0.095507
# Accel_LN_Z_CAL     0.090241
# Gyro_Y_CAL         0.074716
# Gyro_X_CAL         0.065622
# dtype: float64

# %%
sorted_idx = rf.feature_importances_.argsort()
plt.barh(merged_df.columns[sorted_idx], rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import PolynomialFeatures
from pandas import DataFrame
from sklearn.pipeline import Pipeline
from sklearn import metrics

# generate dataset
X, y = merged_df.iloc[:, :-1], merged_df.iloc[:, -1]
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.33, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.33, random_state=0)

svclassifier = SVC(kernel='linear')
svclassifier.fit(X_train, y_train)
y_pred = svclassifier.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.7581699346405228
# Recall: 1.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import PolynomialFeatures
from pandas import DataFrame
from sklearn.pipeline import Pipeline
from sklearn import metrics

# generate dataset
X, y = merged_df.iloc[:, :-1], merged_df.iloc[:, -1]
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.33, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.33, random_state=0)

svclassifier = SVC(kernel='poly', degree=4)
svclassifier.fit(X_train, y_train)
y_pred = svclassifier.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.8163992869875223
# Recall: 0.9717868338557993

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import PolynomialFeatures
from pandas import DataFrame
from sklearn.pipeline import Pipeline
from sklearn import metrics

# generate dataset
X, y = merged_df.iloc[:, :-1], merged_df.iloc[:, -1]
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.33, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.33, random_state=0)

svclassifier = SVC(kernel='rbf')
svclassifier.fit(X_train, y_train)
y_pred = svclassifier.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.8401663695781343
# Recall: 0.9968652037617555

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import PolynomialFeatures
from pandas import DataFrame
from sklearn.pipeline import Pipeline
from sklearn import metrics

# generate dataset
X, y = merged_df.iloc[:, :-1], merged_df.iloc[:, -1]
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.33, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.33, random_state=0)

svclassifier = SVC(kernel='sigmoid')
svclassifier.fit(X_train, y_train)
y_pred = svclassifier.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.6595365418894831
# Recall: 0.8213166144200627

# %%
# Out:
# 204

# %%
#cc = df_stand.groupby(['event','event_date','event_time']).cumcount() + 1
df = df_stand.set_index([20]).unstack().sort_index(1, level=1)
df.columns = ['_'.join(map(str,i)) for i in df.columns]
df.reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-5ebc8f7eee95> in <module>
#       1 #cc = df_stand.groupby(['event','event_date','event_time']).cumcount() + 1
# ----> 2 df = df_stand.set_index([20]).unstack().sort_index(1, level=1)
#       3 df.columns = ['_'.join(map(str,i)) for i in df.columns]
#       4 df.reset_index()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: 'None of [20] are in the columns'

# %%
scaler = preprocessing.StandardScaler()
d_stand = scaler.fit_transform(df_stand)
d_sit = scaler.fit_transform(df_sit)
d_upstair = scaler.fit_transform(df_upstair)
d_walk = scaler.fit_transform(df_walk)
d_facet = scaler.fit_transform(df_facet)
d_schead = scaler.fit_transform(df_schead)
d_rubface = scaler.fit_transform(df_rubface)
d_scface = scaler.fit_transform(df_scface)
d_check_phone = scaler.fit_transform(df_check_phone)
d_clean_window = scaler.fit_transform(df_clean_window)
d_cooking = scaler.fit_transform(df_cooking)
d_only_close_door = scaler.fit_transform(df_only_close_door)
d_only_open_door = scaler.fit_transform(df_only_open_door)
d_pick_chocolate = scaler.fit_transform(df_pick_chocolate)
d_place_item = scaler.fit_transform(df_place_item)
d_typing = scaler.fit_transform(df_typing)
d_walk_downstairs = scaler.fit_transform(df_walk_downstairs)

scaled_df_stand = pd.DataFrame(d_stand, columns=names)
scaled_df_sit = pd.DataFrame(d_sit, columns=names)
scaled_df_upstair = pd.DataFrame(d_upstair, columns=names)
scaled_df_walk = pd.DataFrame(d_walk, columns=names)
scaled_df_facet = pd.DataFrame(d_facet, columns=names)
scaled_df_schead = pd.DataFrame(d_schead, columns=names)
scaled_df_rubface = pd.DataFrame(d_rubface, columns=names)
scaled_df_scface = pd.DataFrame(d_scface, columns=names)
scaled_df_check_phone = pd.DataFrame(d_check_phone, columns=names)
scaled_df_clean_window = pd.DataFrame(d_clean_window, columns=names)
scaled_df_cooking = pd.DataFrame(d_cooking, columns=names)
scaled_df_only_close_door = pd.DataFrame(d_only_close_door, columns=names)
scaled_df_only_open_door = pd.DataFrame(d_only_open_door, columns=names)
scaled_df_pick_chocolate = pd.DataFrame(d_pick_chocolate, columns=names)
scaled_df_place_item = pd.DataFrame(d_place_item, columns=names)
scaled_df_typing = pd.DataFrame(d_typing, columns=names)
scaled_df_walk_downstairs = pd.DataFrame(d_walk_downstairs, columns=names)

uni_features=['Accel_LN_X_CAL', 'Accel_LN_Y_CAL', 'Accel_LN_Z_CAL','Gyro_X_CAL', 'Gyro_Y_CAL', 'Gyro_Z_CAL']

# %%
new1 = scaled_df_stand.filter(uni_features)
new2 = scaled_df_sit.filter(uni_features)
new3 = scaled_df_upstair.filter(uni_features)
new4 = scaled_df_walk.filter(uni_features)
new5 = scaled_df_check_phone.filter(uni_features)
new6 = scaled_df_clean_window.filter(uni_features)
new7 = scaled_df_cooking.filter(uni_features)
new8 = scaled_df_only_close_door.filter(uni_features)
new9 = scaled_df_only_open_door.filter(uni_features)
new10 = scaled_df_pick_chocolate.filter(uni_features)
new11 = scaled_df_place_item.filter(uni_features)
new12 = scaled_df_typing.filter(uni_features)
new13 = scaled_df_walk_downstairs.filter(uni_features)
new14 = scaled_df_facet.filter(uni_features)
new15 = scaled_df_schead.filter(uni_features)
new16 = scaled_df_rubface.filter(uni_features)
new17 = scaled_df_scface.filter(uni_features)

frames= [new1, new2, new3, new4, new5, new6, new7, new8, new9, new10, new11, new12, new13, new14, new15, new16, new17]

# %%
s_rate= 200
n= (len(df_stand.index)//s_rate)

# %%
ls=list()
for df in frames:
    for i in range(n):
        df1 = df.iloc[i*s_rate:(i+1)*s_rate,]
        lst=df1.values.flatten().tolist()
        if df.equals(new14) | df.equals(new15) | df.equals(new16) | df.equals(new17):
            lst.insert(len(lst), 1)
        else:
            lst.insert(len(lst), 0)
        ls.append(lst)
    

ls= np.array(ls)

# %%
from sklearn.model_selection import train_test_split
X, y = ls[:, :-1], ls[:, -1]
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.33, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.33, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=1000)

lr.fit(X_train_val, y_train_val)

print("Training Score:{:.3f}".format(lr.score(X_train, y_train)))
print("Validation Score:{:.3f}".format(lr.score(X_val, y_val)))
print("Testing Score:{:.3f}".format(lr.score(X_test, y_test)))
# Out:
# Training Score:1.000
# Validation Score:1.000
# Testing Score:0.726
